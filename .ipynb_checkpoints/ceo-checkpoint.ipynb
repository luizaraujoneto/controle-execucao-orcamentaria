# %%
import os

# Defina o diretório onde os arquivos estão localizados
diretorio = '.'

# Lista todos os arquivos no diretório que terminam com '.xlsx'
arquivos_xlsx = [f for f in os.listdir(diretorio) if f.endswith('.xlsx')]

# Exibe a lista de arquivos
print(arquivos_xlsx)
# Out:
# ['analise-trimestral-de-indicadores-setembro.xlsx', 'arquivo-execucao-orcamentaria-tre-al.xlsx', 'despesas-liquidadas-modelo.xlsx', 'execucao-por-empenho-tre-al.xlsx', 'pagamentos-por-credor.xlsx', 'pre-empenhos-ativos.xlsx']

# %%
import pandas as pd

# Replace the file path with the location of your Excel file
file_path = 'arquivo-execucao-orcamentaria-tre-al.xlsx'

# Read the Excel file
df = pd.read_excel(file_path, header=1)

print(df.columns)
# Out:
# Index(['Mês Lançamento', 'Ação Governo Código', 'Ação Governo Nome',
#        'UG Responsável Código', 'UG Responsável Nome', 'PI Código PI',
#        'PI Nome', 'Grupo Despesa Código Grupo', 'Grupo Despesa Nome',
#        'Natureza Despesa Código', 'Natureza Despesa Nome', 'Conta Contábil',
#        'Saldo - R$ (Conta Contábil)'],
#       dtype='object')

# %%
filtro = df[df['UG Responsável Nome'].str.contains('Corporativas', case=False) & (df['Mês Lançamento'] == 'OUT/2024')]

# Display the content
print(filtro)
# Out:
#      Mês Lançamento Ação Governo Código  \
# 6390       OUT/2024                20GP
# 6391       OUT/2024                20GP
# 6392       OUT/2024                20GP
# 6393       OUT/2024                20GP
# 6394       OUT/2024                20GP
# 6395       OUT/2024                20GP
# 6396       OUT/2024                20GP
# 6397       OUT/2024                20GP
# 6398       OUT/2024                20GP
# 6399       OUT/2024                20GP
# 6400       OUT/2024                20GP
# 6401       OUT/2024                20GP
# 6402       OUT/2024                20GP
# 6403       OUT/2024                20GP
# 6404       OUT/2024                20GP
# 6405       OUT/2024                20GP
# 6406       OUT/2024                20GP
# 6407       OUT/2024                20GP
# 6408       OUT/2024                20GP
# 6409       OUT/2024                20GP
# 6410       OUT/2024                20GP
# 6411       OUT/2024                20GP
# 6412       OUT/2024                20GP
#
#                                       Ação Governo Nome UG Responsável Código  \
# 6390  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6391  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6392  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6393  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6394  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6395  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6396  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6397  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6398  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6399  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6400  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6401  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6402  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6403  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6404  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6405  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6406  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6407  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6408  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6409  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6410  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6411  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
# 6412  JULGAMENTO DE CAUSAS E GESTAO ADMINISTRATIVA N...                070289
#
#                              UG Responsável Nome PI Código PI  \
# 6390  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   INV SOFTWR
# 6391  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   INV SOFTWR
# 6392  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   INV SOFTWR
# 6393  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC ARMDAD
# 6394  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC ARMDAD
# 6395  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC ARMDAD
# 6396  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC ARMDAD
# 6397  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC ARMDAD
# 6398  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC ARMDAD
# 6399  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC ARMDAD
# 6400  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC ARMDAD
# 6401  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC ARMDAD
# 6402  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC ARMDAD
# 6403  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC COMRED
# 6404  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC COMRED
# 6405  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC COMRED
# 6406  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC COMRED
# 6407  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC COMRED
# 6408  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC COMRED
# 6409  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC LOCSOF
# 6410  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC LOCSOF
# 6411  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC LOCSOF
# 6412  UGR - COORD. SOLUC. CORPORATIVAS DO TRE-AL   TIC MANSOF
#
#                                       PI Nome  Grupo Despesa Código Grupo  \
# 6390  AQUISICAO E DESENVOLVIMENTO DE SOFTWARE                           4
# 6391  AQUISICAO E DESENVOLVIMENTO DE SOFTWARE                           4
# 6392  AQUISICAO E DESENVOLVIMENTO DE SOFTWARE                           4
# 6393                   ARMAZENAMENTO DE DADOS                           3
# 6394                   ARMAZENAMENTO DE DADOS                           3
# 6395                   ARMAZENAMENTO DE DADOS                           3
# 6396                   ARMAZENAMENTO DE DADOS                           3
# 6397                   ARMAZENAMENTO DE DADOS                           3
# 6398                   ARMAZENAMENTO DE DADOS                           3
# 6399                   ARMAZENAMENTO DE DADOS                           3
# 6400                   ARMAZENAMENTO DE DADOS                           3
# 6401                   ARMAZENAMENTO DE DADOS                           3
# 6402                   ARMAZENAMENTO DE DADOS                           3
# 6403             COMUNICACAO E REDES DE DADOS                           3
# 6404             COMUNICACAO E REDES DE DADOS                           3
# 6405             COMUNICACAO E REDES DE DADOS                           3
# 6406             COMUNICACAO E REDES DE DADOS                           3
# 6407             COMUNICACAO E REDES DE DADOS                           3
# 6408             COMUNICACAO E REDES DE DADOS                           3
# 6409         LOCACAO E SUBSCRICAO DE SOFTWARE                           3
# 6410         LOCACAO E SUBSCRICAO DE SOFTWARE                           3
# 6411         LOCACAO E SUBSCRICAO DE SOFTWARE                           3
# 6412     MANUTENCAO E SUSTENTACAO DE SOFTWARE                           3
#
#              Grupo Despesa Nome  Natureza Despesa Código  \
# 6390              INVESTIMENTOS                   449040
# 6391              INVESTIMENTOS                   449040
# 6392              INVESTIMENTOS                   449040
# 6393  OUTRAS DESPESAS CORRENTES                   339040
# 6394  OUTRAS DESPESAS CORRENTES                   339040
# 6395  OUTRAS DESPESAS CORRENTES                   339040
# 6396  OUTRAS DESPESAS CORRENTES                   339040
# 6397  OUTRAS DESPESAS CORRENTES                   339040
# 6398  OUTRAS DESPESAS CORRENTES                   339093
# 6399  OUTRAS DESPESAS CORRENTES                   339093
# 6400  OUTRAS DESPESAS CORRENTES                   339093
# 6401  OUTRAS DESPESAS CORRENTES                   339093
# 6402  OUTRAS DESPESAS CORRENTES                   339093
# 6403  OUTRAS DESPESAS CORRENTES                   339040
# 6404  OUTRAS DESPESAS CORRENTES                   339040
# 6405  OUTRAS DESPESAS CORRENTES                   339040
# 6406  OUTRAS DESPESAS CORRENTES                   339040
# 6407  OUTRAS DESPESAS CORRENTES                   339040
# 6408  OUTRAS DESPESAS CORRENTES                   339040
# 6409  OUTRAS DESPESAS CORRENTES                   339040
# 6410  OUTRAS DESPESAS CORRENTES                   339040
# 6411  OUTRAS DESPESAS CORRENTES                   339040
# 6412  OUTRAS DESPESAS CORRENTES                   339040
#
#                                   Natureza Despesa Nome  \
# 6390  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6391  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6392  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6393  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6394  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6395  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6396  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6397  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6398                        INDENIZACOES E RESTITUICOES
# 6399                        INDENIZACOES E RESTITUICOES
# 6400                        INDENIZACOES E RESTITUICOES
# 6401                        INDENIZACOES E RESTITUICOES
# 6402                        INDENIZACOES E RESTITUICOES
# 6403  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6404  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6405  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6406  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6407  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6408  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6409  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6410  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6411  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
# 6412  SERVICOS DE TECNOLOGIA DA INFORMACAO E COMUNIC...
#
#                               Conta Contábil  Saldo - R$ (Conta Contábil)
# 6390                   '= CREDITO DISPONIVEL                    570466.00
# 6391                '= CREDITO PRE-EMPENHADO                         0.00
# 6392         '= CREDITO EMPENHADO A LIQUIDAR                      2678.00
# 6393                   '= CREDITO DISPONIVEL                    134880.37
# 6394         '= CREDITO EMPENHADO A LIQUIDAR                      1266.50
# 6395      '= CREDITO EMPENHADO EM LIQUIDACAO                         0.00
# 6396  '= CREDITO EMPENHADO LIQUIDADO A PAGAR                         0.00
# 6397     '= CREDITO EMPENHADO LIQUIDADO PAGO                      3518.40
# 6398                   '= CREDITO DISPONIVEL                         0.00
# 6399         '= CREDITO EMPENHADO A LIQUIDAR                         0.00
# 6400      '= CREDITO EMPENHADO EM LIQUIDACAO                         0.00
# 6401  '= CREDITO EMPENHADO LIQUIDADO A PAGAR                         0.00
# 6402     '= CREDITO EMPENHADO LIQUIDADO PAGO                       153.00
# 6403                   '= CREDITO DISPONIVEL                         0.00
# 6404                '= CREDITO PRE-EMPENHADO                         0.00
# 6405         '= CREDITO EMPENHADO A LIQUIDAR                      7015.35
# 6406      '= CREDITO EMPENHADO EM LIQUIDACAO                         0.00
# 6407  '= CREDITO EMPENHADO LIQUIDADO A PAGAR                       211.58
# 6408     '= CREDITO EMPENHADO LIQUIDADO PAGO                     19405.76
# 6409                   '= CREDITO DISPONIVEL                         0.00
# 6410                '= CREDITO PRE-EMPENHADO                         0.00
# 6411         '= CREDITO EMPENHADO A LIQUIDAR                      6280.00
# 6412                   '= CREDITO DISPONIVEL                     98818.00

# %%
resultado = filtro.groupby('Conta Contábil')['Saldo - R$ (Conta Contábil)'].sum()
print(resultado)
# Out:
# Conta Contábil
# '= CREDITO DISPONIVEL                     804164.37
# '= CREDITO EMPENHADO A LIQUIDAR            17239.85
# '= CREDITO EMPENHADO EM LIQUIDACAO             0.00
# '= CREDITO EMPENHADO LIQUIDADO A PAGAR       211.58
# '= CREDITO EMPENHADO LIQUIDADO PAGO        23077.16
# '= CREDITO PRE-EMPENHADO                       0.00
# Name: Saldo - R$ (Conta Contábil), dtype: float64

# %%
resultado2 = filtro[filtro['Conta Contábil'].str.contains('EMPENHADO A LIQUIDAR') ].groupby('PI Nome')['Saldo - R$ (Conta Contábil)'].sum()
print(resultado2)
# Out:
# PI Nome
# AQUISICAO E DESENVOLVIMENTO DE SOFTWARE    2678.00
# ARMAZENAMENTO DE DADOS                     1266.50
# COMUNICACAO E REDES DE DADOS               7015.35
# LOCACAO E SUBSCRICAO DE SOFTWARE           6280.00
# Name: Saldo - R$ (Conta Contábil), dtype: float64
